# %%
import requests
import pandas as pd

# %%
api='https://data.binance.com/api/v3/ticker/24hr'
response=requests.get(api)

# %%
if response.status_code !=200:
  raise Exception('faild to fetch dta')

# %%
data =pd.DataFrame(response.json())

# %%
data
# Out:
#          symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0        ETHBTC  -0.00041000             -0.683       0.05985521
# 1        LTCBTC   0.00004000              1.678       0.00238296
# 2        BNBBTC  -0.00003000             -0.377       0.00791392
# 3        NEOBTC   0.00000060              0.218       0.00027830
# 4       QTUMETH   0.00001100              0.811       0.00136925
# ...         ...          ...                ...              ...
# 2292    UNFITRY   2.00000000              0.949     209.11249513
# 2293   XRPFDUSD  -0.01070000             -2.074       0.51403003
# 2294  DOGEFDUSD  -0.00057000             -0.915       0.06252831
# 2295   CYBERETH   0.00007300              2.301       0.00323494
# 2296     MTLTRY   1.04000000              3.055      35.44976393
#
#      prevClosePrice     lastPrice        lastQty      bidPrice         bidQty  \
# 0        0.06002000    0.05961000     0.15770000    0.05961000     6.69530000
# ...

# %%
data.to_csv('coin.csv')

# %%
df=pd.read_csv('/content/coin.csv')

# %%
df
# Out:
#       Unnamed: 0     symbol   priceChange  priceChangePercent  \
# 0              0     ETHBTC -4.100000e-04              -0.683
# 1              1     LTCBTC  4.000000e-05               1.678
# 2              2     BNBBTC -3.000000e-05              -0.377
# 3              3     NEOBTC  6.000000e-07               0.218
# 4              4    QTUMETH  1.100000e-05               0.811
# ...          ...        ...           ...                 ...
# 2292        2292    UNFITRY  2.000000e+00               0.949
# 2293        2293   XRPFDUSD -1.070000e-02              -2.074
# 2294        2294  DOGEFDUSD -5.700000e-04              -0.915
# 2295        2295   CYBERETH  7.300000e-05               2.301
# 2296        2296     MTLTRY  1.040000e+00               3.055
#
#       weightedAvgPrice  prevClosePrice   lastPrice    lastQty    bidPrice  \
# 0             0.059855        0.060020    0.059610     0.1577    0.059610
# ...
